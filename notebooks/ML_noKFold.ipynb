# %% [markdown]
# # Table of contents
#
# 1. [Data overview](#data_overview)
#     1. [Performance of the top classifiers](#performance)
#     2. [Finding the best subset](#finding)
# 2. [Reconstructing the top models](#reconstructing)
#     1. [ROC curves](#roc_curves)
# 3. [Supplementary data](#supplementary)
#     1. [Correlations](#correlations)
#     2. [Comparing classifiers](#comparing)
#     3. [Performance of the top classifiers](#top_classifiers)
#     4. [Docking scores and performance increment](#docking)
#     5. [Top descriptors](#top_descriptors)
#
# <a id='scoring_metrics'></a>
# ## Scoring metrics
#
# * Accuracy score: true positives / total
# * Precision: low false positive rate
# * Recall (sensitivity): true positives / all positives
# * F1 score: weighted avg of precision and recall ~ better than accuracy for uneven class distribution
# * Roc_auc: TPR / FPR

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
files = '../files'

# Read data
data = pd.read_csv(f'{files}/data.csv')

# Read descriptors
descriptors = pd.read_csv(f'{files}/descriptors.csv')

# Descriptors
descriptors_list = list(descriptors.columns[2:])
docking_list = ['qvina','rfscore_qvina','plants','rfscore_plants']
trainset = descriptors_list + docking_list

# Test metrics
scoring_metrics = ['test_accuracy','test_precision','test_recall','test_f1','test_f2',
                   'test_geometric_mean','test_roc_auc']
columns = ['activity_label', 'model', 'random_state', scoring_metrics] + trainset

# %% [markdown]
# <a id='data_overview'></a>
# ## Data overview

# %%
# Read test scores and sort values
scores_data = pd.read_csv(f'{files}/scores_data/scores_data.csv.gz', compression='gzip')

model_list = scores_data['model'].unique()
columns = scores_data.columns
selected = ['test_f2', 'test_geometric_mean', 'test_roc_auc']
test_metrics = selected + ['test_mean']
train_metrics = [metric.replace('test', 'train') for metric in test_metrics]

scores_data['test_mean'] = scores_data[selected].mean(axis=1)
scores_data.sort_values('test_mean', ascending=False, inplace=True)
scores_data.head()
# Out:
#       test_accuracy  test_precision  test_recall   test_f1   test_f2  \
# 313        0.687540        0.333471     0.665642  0.441712  0.551862
# 2372       0.683889        0.329452     0.665823  0.438286  0.549731
# 1946       0.689127        0.332555     0.656939  0.438801  0.546274
# 597        0.694762        0.336235     0.645020  0.440257  0.542806
# 146        0.693651        0.335213     0.643214  0.437713  0.539751
#
#       test_geometric_mean  test_roc_auc activity_label                 model  \
# 313              0.675851      0.679020     f_activity  KNeighborsClassifier
# 2372             0.675075      0.677749     f_activity  KNeighborsClassifier
# 1946             0.674372      0.677490     f_activity  KNeighborsClassifier
# 597              0.673417      0.675698     f_activity  KNeighborsClassifier
# 146              0.671449      0.674721     f_activity  KNeighborsClassifier
#
#       NumRotatableBonds  NumHAcceptors  NumHDonors  TPSA  LabuteASA  MolLogP  \
# 313                   0              0           0     1          1        0
# 2372                  0              1           0     1          1        0
# 1946                  1              0           0     1          1        0
# 597                   1              1           1     0          0        1
# 146                   1              1           1     0          0        1
#
#       qvina  rfscore_qvina  plants  rfscore_plants  test_mean
# 313       0              0       0               0   0.635578
# 2372      0              0       0               0   0.634185
# 1946      0              0       0               0   0.632712
# 597       1              1       0               0   0.630640
# 146       1              0       0               0   0.628640

# %%
tmp = pd.melt(scores_data, value_vars=scoring_metrics)
g = sns.FacetGrid(data=tmp, col='variable', col_wrap=4, sharex=False, sharey=False)
del tmp
g.map(sns.histplot, 'value', kde=True)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Distribution of the scoring metrics', y=1.05)
plt.show()

# %% [markdown]
# <a id='performance'></a>
# ### Performance of the top classifiers

# %%
from sklearn.preprocessing import StandardScaler

df = scores_data[['activity_label','model',*test_metrics]].copy()
df[test_metrics] = StandardScaler().fit_transform(df[test_metrics])
top = pd.melt(df.groupby(['activity_label', 'model']).head(1), 
              id_vars=['activity_label','model'], value_vars=test_metrics)
sns.catplot(kind='point', data=top.sort_values('value', ascending=False), x='variable', y='value', 
            hue='model', row='activity_label', aspect=2, order=test_metrics, hue_order=model_list)
plt.suptitle('Model performance by scoring metric', y=1.05)
# Out:
# Text(0.5, 1.05, 'Model performance by scoring metric')

# %% [markdown]
# <a id='finding'></a>
# ### Finding the best subset

# %%
# Dictionary: key == model_name, value == list of best descriptors
best_subset = {}
activity_label = 'f_activity'

for i, row in scores_data.query('activity_label == @activity_label').groupby('model').head(1).iterrows():
    model_name = row['model']
    best_subset[model_name] = [descriptor for descriptor in trainset if row[descriptor]]
    print(model_name, best_subset[model_name])
# Out:
# KNeighborsClassifier ['TPSA', 'LabuteASA']
# LogisticRegression ['NumHAcceptors', 'NumHDonors', 'LabuteASA', 'MolLogP', 'rfscore_qvina']
# LinearSVC ['NumHAcceptors', 'NumHDonors', 'LabuteASA', 'MolLogP', 'rfscore_qvina']
# XGBClassifier ['NumHDonors', 'TPSA', 'LabuteASA', 'plants']
# LinearDiscriminantAnalysis ['NumHAcceptors', 'NumHDonors', 'TPSA', 'LabuteASA', 'MolLogP', 'qvina', 'rfscore_qvina']
# RandomForestClassifier ['NumHDonors', 'TPSA', 'LabuteASA', 'plants']
# DecisionTreeClassifier ['NumHDonors', 'LabuteASA', 'qvina']

# %% [markdown]
# <a id='reconstructing'></a>
# ## Reconstructing the top models

# %%
def get_model_opt_by_name(model_name):
    if model_name == 'RandomForestClassifier':
        from sklearn.ensemble import RandomForestClassifier
        return RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=13)
    elif model_name == 'KNeighborsClassifier':
        from sklearn.neighbors import KNeighborsClassifier
        return KNeighborsClassifier(n_neighbors=5)
    elif model_name == 'XGBClassifier':
        from xgboost import XGBClassifier
        return XGBClassifier(objective='reg:logistic', n_estimators=100, 
            max_depth=3, eta=0.2, random_state=13)
    elif model_name == 'DecisionTreeClassifier':
        from sklearn.tree import DecisionTreeClassifier
        return DecisionTreeClassifier(max_depth=5, random_state=13)
    elif model_name == 'LogisticRegression':
        from sklearn.linear_model import LogisticRegression
        return LogisticRegression(solver='liblinear', random_state=13)
    elif model_name == 'LinearSVC':
        from sklearn.svm import LinearSVC
        from sklearn.calibration import CalibratedClassifierCV
        # CalibratedClassifierCV is used for applying probability transformation 
        # on top of the SVC outputs, so we can plot the ROC curve
        # https://stackoverflow.com/a/39712590/13131079
        return CalibratedClassifierCV(base_estimator=LinearSVC(dual=False, random_state=13))
    elif model_name == 'LinearDiscriminantAnalysis':
        from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
        return LinearDiscriminantAnalysis(solver='svd')
    else:
        return None

# %%
def train_test_scores(X_train, X_test, y_train, y_test, model_fitted):
    from sklearn.metrics import fbeta_score
    from imblearn.metrics import geometric_mean_score
    
    scores_list = []
    y_pred_test = model_fitted.predict(X_test)
    y_pred_train = model_fitted.predict(X_train)
    
    scores_list.append(fbeta_score(y_test, y_pred_test, beta=2))       # test_f2
    scores_list.append(fbeta_score(y_train, y_pred_train, beta=2))     # train_f2
    scores_list.append(geometric_mean_score(y_test, y_pred_test))      # test_geometric_mean
    scores_list.append(geometric_mean_score(y_train, y_pred_train))    # train_geometric_mean
    return scores_list

def plot_train_test_roc(axis, X_train, X_test, y_train, y_test, model_fitted, model_name):
    from sklearn.metrics import roc_curve, auc
    # Test ROC
    y_proba_test = model_fitted.predict_proba(X_test)
    fpr_test, tpr_test, _ = roc_curve(y_test, y_proba_test[:,1])
    test_auc = auc(fpr_test, tpr_test)
    axis[0].plot(fpr_test, tpr_test, label=model_name)

    # Training ROC
    y_proba_train = model_fitted.predict_proba(X_train)
    fpr_train, tpr_train, _ = roc_curve(y_train, y_proba_train[:,1])
    train_auc = auc(fpr_train, tpr_train)
    axis[1].plot(fpr_train, tpr_train, label=model_name)
    
    return test_auc, train_auc
    
def get_mean_scores(X, y, scaler, model, model_name, axis):
    from imblearn.over_sampling import SMOTE
    from imblearn.pipeline import make_pipeline
    from sklearn.model_selection import train_test_split

    pipe = make_pipeline(SMOTE(random_state=42), scaler, model)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)
    model_fitted = pipe.fit(X_train, y_train)
    # Test and training scores
    scores_list = train_test_scores(X_train, X_test, y_train, y_test, model_fitted)
    
    # Plot mean ROC curve
    test_auc, train_auc = plot_train_test_roc(axis, X_train, X_test, y_train, y_test, 
                                              model_fitted, model_name)
    # Append mean AUC
    scores_list.append(test_auc)
    scores_list.append(train_auc)
    scores_list.append(model_name)
    return scores_list

# %% [markdown]
# <a id='roc_curves'></a>
# ### ROC curves

# %%
fig, ax = plt.subplots(ncols=2, figsize=(12.8, 4.8))
# List of scores for the top models
scores_list = []

for model_name in model_list:
    subset = best_subset[model_name]
    y = data[activity_label]
    X = data[subset]
    scaler = StandardScaler()
    model = get_model_by_name(model_name)
    model_scores = get_mean_scores(X, y, scaler, model, model_name, axis=ax)
    scores_list.append(model_scores)

columns = ['test_f2', 'train_f2', 'test_geometric_mean', 'train_geometric_mean', 
           'test_roc_auc', 'train_roc_auc', 'model']
top_scores = pd.DataFrame(scores_list, columns=columns)
top_scores['test_mean'] = top_scores[test_metrics[:-1]].mean(axis=1)
top_scores['train_mean'] = top_scores[train_metrics[:-1]].mean(axis=1)




ax[0].set(title='Test data', xlabel='False Positive Rate', ylabel='True Positive Rate')
ax[0].plot([0,1], [0,1], linestyle='--')
ax[1].set(title='Train data', xlabel='False Positive Rate', ylabel='True Positive Rate')
ax[1].plot([0,1], [0,1], linestyle='--')

handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles, labels, title='Model', bbox_to_anchor=(1.05, 1))
plt.suptitle('Receiver Operating Characteristic')
plt.savefig('figures/roc_curve_noKFold.png',  bbox_inches='tight', dpi=128)
plt.show()

top_scores
# Out:
#     test_f2  train_f2  test_geometric_mean  train_geometric_mean  \
# 0  0.515873  0.500849             0.669060              0.633343
# 1  0.492424  0.744501             0.640975              0.810440
# 2  0.483871  0.495726             0.647200              0.631356
# 3  0.384615  0.774021             0.557961              0.842233
# 4  0.503876  0.519802             0.655168              0.638861
# 5  0.500000  0.727580             0.650472              0.798529
# 6  0.447761  0.703002             0.601884              0.757886
#
#    test_roc_auc  train_roc_auc                       model  test_mean  \
# 0      0.688679       0.667824          LogisticRegression   0.624537
# 1      0.637264       0.913440      RandomForestClassifier   0.590221
# 2      0.686321       0.667849                   LinearSVC   0.605797
# 3      0.608962       0.930510        KNeighborsClassifier   0.517180
# 4      0.682547       0.670411  LinearDiscriminantAnalysis   0.613864
# 5      0.663208       0.887009               XGBClassifier   0.604560
# 6      0.625236       0.848975      DecisionTreeClassifier   0.558294
#
#    train_mean
# 0    0.600672
# 1    0.822794
# 2    0.598311
# 3    0.848921
# 4    0.609691
# 5    0.804373
# 6    0.769954

# %%
print(top_scores[['model','test_f2','test_geometric_mean','test_roc_auc','test_mean']].to_latex(index=False, float_format='%.3f'))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
#                       model &  test\_f2 &  test\_geometric\_mean &  test\_roc\_auc &  test\_mean \\
# \midrule
#          LogisticRegression &    0.516 &                0.669 &         0.689 &      0.625 \\
#      RandomForestClassifier &    0.492 &                0.641 &         0.637 &      0.590 \\
#                   LinearSVC &    0.484 &                0.647 &         0.686 &      0.606 \\
#        KNeighborsClassifier &    0.385 &                0.558 &         0.609 &      0.517 \\
#  LinearDiscriminantAnalysis &    0.504 &                0.655 &         0.683 &      0.614 \\
#               XGBClassifier &    0.500 &                0.650 &         0.663 &      0.605 \\
#      DecisionTreeClassifier &    0.448 &                0.602 &         0.625 &      0.558 \\
# \bottomrule
# \end{tabular}

# %%
print(top_scores[['model','train_f2','train_geometric_mean','train_roc_auc','train_mean']].to_latex(index=False, float_format='%.3f'))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
#                       model &  train\_f2 &  train\_geometric\_mean &  train\_roc\_auc &  train\_mean \\
# \midrule
#          LogisticRegression &     0.501 &                 0.633 &          0.668 &       0.601 \\
#      RandomForestClassifier &     0.745 &                 0.810 &          0.913 &       0.823 \\
#                   LinearSVC &     0.496 &                 0.631 &          0.668 &       0.598 \\
#        KNeighborsClassifier &     0.774 &                 0.842 &          0.931 &       0.849 \\
#  LinearDiscriminantAnalysis &     0.520 &                 0.639 &          0.670 &       0.610 \\
#               XGBClassifier &     0.728 &                 0.799 &          0.887 &       0.804 \\
#      DecisionTreeClassifier &     0.703 &                 0.758 &          0.849 &       0.770 \\
# \bottomrule
# \end{tabular}

# %%
from sklearn.metrics import roc_curve, auc

# Plotting ROC curves for the docking scoring functions
for SF in docking_list:
    fpr, tpr, _ = roc_curve(data[activity_label].values, data[SF].values)
    plt.plot(fpr, tpr, label=f'{SF}: {auc(fpr, tpr):>.3f}')
    
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
font_prop = {'weight':'bold'}
plt.legend(title='Docking functions', loc='lower right', prop=font_prop)

# %% [markdown]
# <a id='supplementary'></a>
# ## Supplementary data
# <a id='comparing'></a>
# ### Comparing classifiers

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(scores_data.groupby(['model','activity_label']).describe())
# Out:
#                                           test_accuracy                      \
#                                                   count      mean       std
# model                      activity_label
# DecisionTreeClassifier     f_activity             437.0  0.593533  0.026637
# KNeighborsClassifier       f_activity             437.0  0.636695  0.029022
# LinearDiscriminantAnalysis f_activity             437.0  0.593873  0.041404
# LinearSVC                  f_activity             437.0  0.595495  0.042183
# LogisticRegression         f_activity             437.0  0.598529  0.042571
# RandomForestClassifier     f_activity             437.0  0.654037  0.030491
# XGBClassifier              f_activity             437.0  0.661697  0.029706
#
#                                                                          \
#                                                 min       25%       50%
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.504127  0.577222  0.598175
# KNeighborsClassifier       f_activity      0.541111  0.620397  0.640317
# LinearDiscriminantAnalysis f_activity      0.466032  0.575000  0.597857
# LinearSVC                  f_activity      0.467381  0.576270  0.600317
# LogisticRegression         f_activity      0.471349  0.579524  0.605556
# RandomForestClassifier     f_activity      0.549762  0.634841  0.658968
# XGBClassifier              f_activity      0.545238  0.647302  0.667063
#
#                                                               test_precision  \
#                                                 75%       max          count
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.612222  0.663016          437.0
# KNeighborsClassifier       f_activity      0.656667  0.701667          437.0
# LinearDiscriminantAnalysis f_activity      0.621587  0.679127          437.0
# LinearSVC                  f_activity      0.623492  0.683333          437.0
# LogisticRegression         f_activity      0.627143  0.686667          437.0
# RandomForestClassifier     f_activity      0.676429  0.716190          437.0
# XGBClassifier              f_activity      0.684206  0.715556          437.0
#
#                                                                          \
#                                                mean       std       min
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.248322  0.016687  0.192936
# KNeighborsClassifier       f_activity      0.271751  0.029591  0.182105
# LinearDiscriminantAnalysis f_activity      0.254150  0.029021  0.167993
# LinearSVC                  f_activity      0.254712  0.029513  0.168044
# LogisticRegression         f_activity      0.255700  0.030076  0.168206
# RandomForestClassifier     f_activity      0.282689  0.027225  0.196879
# XGBClassifier              f_activity      0.285410  0.026773  0.194239
#
#                                                                          \
#                                                 25%       50%       75%
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.237191  0.250004  0.261068
# KNeighborsClassifier       f_activity      0.253413  0.275825  0.291817
# LinearDiscriminantAnalysis f_activity      0.242403  0.258071  0.272079
# LinearSVC                  f_activity      0.242465  0.258809  0.272955
# LogisticRegression         f_activity      0.241702  0.260140  0.274464
# RandomForestClassifier     f_activity      0.266381  0.284519  0.303575
# XGBClassifier              f_activity      0.272783  0.288270  0.304902
#
#                                                     test_recall            \
#                                                 max       count      mean
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.294367       437.0  0.562492
# KNeighborsClassifier       f_activity      0.336235       437.0  0.551077
# LinearDiscriminantAnalysis f_activity      0.318506       437.0  0.592658
# LinearSVC                  f_activity      0.322893       437.0  0.590559
# LogisticRegression         f_activity      0.326684       437.0  0.586665
# RandomForestClassifier     f_activity      0.341926       437.0  0.536586
# XGBClassifier              f_activity      0.340655       437.0  0.524601
#
#                                                                          \
#                                                 std       min       25%
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.039931  0.375039  0.542148
# KNeighborsClassifier       f_activity      0.056746  0.287915  0.520283
# LinearDiscriminantAnalysis f_activity      0.052086  0.408315  0.566329
# LinearSVC                  f_activity      0.051191  0.408315  0.565208
# LogisticRegression         f_activity      0.049834  0.409215  0.561794
# RandomForestClassifier     f_activity      0.038398  0.384241  0.515013
# XGBClassifier              f_activity      0.037133  0.383173  0.504097
#
#                                                                          \
#                                                 50%       75%       max
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.566375  0.588981  0.663585
# KNeighborsClassifier       f_activity      0.556564  0.589870  0.669202
# LinearDiscriminantAnalysis f_activity      0.599640  0.626809  0.759207
# LinearSVC                  f_activity      0.598090  0.623932  0.759207
# LogisticRegression         f_activity      0.593039  0.619885  0.753524
# RandomForestClassifier     f_activity      0.538265  0.559578  0.640743
# XGBClassifier              f_activity      0.523604  0.545518  0.628222
#
#                                           test_f1                      \
#                                             count      mean       std
# model                      activity_label
# DecisionTreeClassifier     f_activity       437.0  0.338559  0.020709
# KNeighborsClassifier       f_activity       437.0  0.361198  0.037619
# LinearDiscriminantAnalysis f_activity       437.0  0.353420  0.035328
# LinearSVC                  f_activity       437.0  0.353560  0.035614
# LogisticRegression         f_activity       437.0  0.353809  0.036097
# RandomForestClassifier     f_activity       437.0  0.366404  0.029243
# XGBClassifier              f_activity       437.0  0.366185  0.028648
#
#                                                                          \
#                                                 min       25%       50%
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.247244  0.327097  0.341927
# KNeighborsClassifier       f_activity      0.226288  0.339908  0.367172
# LinearDiscriminantAnalysis f_activity      0.242105  0.342548  0.360772
# LinearSVC                  f_activity      0.242156  0.342415  0.360393
# LogisticRegression         f_activity      0.242384  0.340519  0.360951
# RandomForestClassifier     f_activity      0.257206  0.351362  0.370404
# XGBClassifier              f_activity      0.264730  0.353014  0.370410
#
#                                                               test_f2  \
#                                                 75%       max   count
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.352604  0.381101   437.0
# KNeighborsClassifier       f_activity      0.388365  0.441712   437.0
# LinearDiscriminantAnalysis f_activity      0.374464  0.420590   437.0
# LinearSVC                  f_activity      0.374867  0.425904   437.0
# LogisticRegression         f_activity      0.375993  0.430404   437.0
# RandomForestClassifier     f_activity      0.387763  0.423593   437.0
# XGBClassifier              f_activity      0.385325  0.426555   437.0
#
#                                                                          \
#                                                mean       std       min
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.440666  0.027070  0.304849
# KNeighborsClassifier       f_activity      0.453599  0.046367  0.254746
# LinearDiscriminantAnalysis f_activity      0.464571  0.041509  0.325101
# LinearSVC                  f_activity      0.463875  0.041321  0.325119
# LogisticRegression         f_activity      0.462611  0.041304  0.325620
# RandomForestClassifier     f_activity      0.450300  0.032045  0.319010
# XGBClassifier              f_activity      0.445263  0.031222  0.323345
#
#                                                                          \
#                                                 25%       50%       75%
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.429512  0.444057  0.458126
# KNeighborsClassifier       f_activity      0.427088  0.459104  0.485880
# LinearDiscriminantAnalysis f_activity      0.450184  0.473083  0.492651
# LinearSVC                  f_activity      0.448602  0.472119  0.491271
# LogisticRegression         f_activity      0.447232  0.470937  0.490312
# RandomForestClassifier     f_activity      0.434309  0.454845  0.470010
# XGBClassifier              f_activity      0.429717  0.448333  0.464078
#
#                                                     test_geometric_mean  \
#                                                 max               count
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.503213               437.0
# KNeighborsClassifier       f_activity      0.551862               437.0
# LinearDiscriminantAnalysis f_activity      0.532815               437.0
# LinearSVC                  f_activity      0.533860               437.0
# LogisticRegression         f_activity      0.535697               437.0
# RandomForestClassifier     f_activity      0.517584               437.0
# XGBClassifier              f_activity      0.522158               437.0
#
#                                                                          \
#                                                mean       std       min
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.569749  0.024449  0.460620
# KNeighborsClassifier       f_activity      0.597743  0.038564  0.431129
# LinearDiscriminantAnalysis f_activity      0.590399  0.038563  0.463973
# LinearSVC                  f_activity      0.590546  0.038782  0.464069
# LogisticRegression         f_activity      0.590914  0.039188  0.464335
# RandomForestClassifier     f_activity      0.600332  0.028379  0.488421
# XGBClassifier              f_activity      0.599489  0.027532  0.496340
#
#                                                                          \
#                                                 25%       50%       75%
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.556949  0.574480  0.585879
# KNeighborsClassifier       f_activity      0.576230  0.603764  0.625190
# LinearDiscriminantAnalysis f_activity      0.577949  0.599196  0.614380
# LinearSVC                  f_activity      0.576917  0.599338  0.614299
# LogisticRegression         f_activity      0.575339  0.599614  0.615266
# RandomForestClassifier     f_activity      0.586858  0.604515  0.620492
# XGBClassifier              f_activity      0.588698  0.603670  0.617200
#
#                                                     test_roc_auc            \
#                                                 max        count      mean
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.617620        437.0  0.581890
# KNeighborsClassifier       f_activity      0.675851        437.0  0.603892
# LinearDiscriminantAnalysis f_activity      0.655669        437.0  0.593571
# LinearSVC                  f_activity      0.660570        437.0  0.593759
# LogisticRegression         f_activity      0.664577        437.0  0.594123
# RandomForestClassifier     f_activity      0.655841        437.0  0.609094
# XGBClassifier              f_activity      0.660313        437.0  0.609258
#
#                                                                          \
#                                                 std       min       25%
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.020641  0.509426  0.569984
# KNeighborsClassifier       f_activity      0.035300  0.491015  0.583052
# LinearDiscriminantAnalysis f_activity      0.037545  0.467268  0.580693
# LinearSVC                  f_activity      0.037782  0.467369  0.580980
# LogisticRegression         f_activity      0.038174  0.467614  0.580062
# RandomForestClassifier     f_activity      0.026856  0.512408  0.595916
# XGBClassifier              f_activity      0.026224  0.510470  0.598837
#
#                                                                          \
#                                                 50%       75%       max
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.585156  0.596516  0.623661
# KNeighborsClassifier       f_activity      0.609102  0.630012  0.679020
# LinearDiscriminantAnalysis f_activity      0.601958  0.616425  0.658265
# LinearSVC                  f_activity      0.601881  0.616424  0.663206
# LogisticRegression         f_activity      0.602159  0.617225  0.667012
# RandomForestClassifier     f_activity      0.613160  0.628622  0.660515
# XGBClassifier              f_activity      0.613880  0.626668  0.663956
#
#                                           NumRotatableBonds            \
#                                                       count      mean
# model                      activity_label
# DecisionTreeClassifier     f_activity                 437.0  0.510297
# KNeighborsClassifier       f_activity                 437.0  0.510297
# LinearDiscriminantAnalysis f_activity                 437.0  0.510297
# LinearSVC                  f_activity                 437.0  0.510297
# LogisticRegression         f_activity                 437.0  0.510297
# RandomForestClassifier     f_activity                 437.0  0.510297
# XGBClassifier              f_activity                 437.0  0.510297
#
#                                                                               \
#                                                 std  min  25%  50%  75%  max
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.500467  0.0  0.0  1.0  1.0  1.0
# KNeighborsClassifier       f_activity      0.500467  0.0  0.0  1.0  1.0  1.0
# LinearDiscriminantAnalysis f_activity      0.500467  0.0  0.0  1.0  1.0  1.0
# LinearSVC                  f_activity      0.500467  0.0  0.0  1.0  1.0  1.0
# LogisticRegression         f_activity      0.500467  0.0  0.0  1.0  1.0  1.0
# RandomForestClassifier     f_activity      0.500467  0.0  0.0  1.0  1.0  1.0
# XGBClassifier              f_activity      0.500467  0.0  0.0  1.0  1.0  1.0
#
#                                           NumHAcceptors                      \
#                                                   count      mean       std
# model                      activity_label
# DecisionTreeClassifier     f_activity             437.0  0.510297  0.500467
# KNeighborsClassifier       f_activity             437.0  0.510297  0.500467
# LinearDiscriminantAnalysis f_activity             437.0  0.510297  0.500467
# LinearSVC                  f_activity             437.0  0.510297  0.500467
# LogisticRegression         f_activity             437.0  0.510297  0.500467
# RandomForestClassifier     f_activity             437.0  0.510297  0.500467
# XGBClassifier              f_activity             437.0  0.510297  0.500467
#
#                                                                    NumHDonors  \
#                                            min  25%  50%  75%  max      count
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.0  0.0  1.0  1.0  1.0      437.0
# KNeighborsClassifier       f_activity      0.0  0.0  1.0  1.0  1.0      437.0
# LinearDiscriminantAnalysis f_activity      0.0  0.0  1.0  1.0  1.0      437.0
# LinearSVC                  f_activity      0.0  0.0  1.0  1.0  1.0      437.0
# LogisticRegression         f_activity      0.0  0.0  1.0  1.0  1.0      437.0
# RandomForestClassifier     f_activity      0.0  0.0  1.0  1.0  1.0      437.0
# XGBClassifier              f_activity      0.0  0.0  1.0  1.0  1.0      437.0
#
#                                                                               \
#                                                mean       std  min  25%  50%
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.510297  0.500467  0.0  0.0  1.0
# KNeighborsClassifier       f_activity      0.510297  0.500467  0.0  0.0  1.0
# LinearDiscriminantAnalysis f_activity      0.510297  0.500467  0.0  0.0  1.0
# LinearSVC                  f_activity      0.510297  0.500467  0.0  0.0  1.0
# LogisticRegression         f_activity      0.510297  0.500467  0.0  0.0  1.0
# RandomForestClassifier     f_activity      0.510297  0.500467  0.0  0.0  1.0
# XGBClassifier              f_activity      0.510297  0.500467  0.0  0.0  1.0
#
#                                                       TPSA            \
#                                            75%  max  count      mean
# model                      activity_label
# DecisionTreeClassifier     f_activity      1.0  1.0  437.0  0.510297
# KNeighborsClassifier       f_activity      1.0  1.0  437.0  0.510297
# LinearDiscriminantAnalysis f_activity      1.0  1.0  437.0  0.510297
# LinearSVC                  f_activity      1.0  1.0  437.0  0.510297
# LogisticRegression         f_activity      1.0  1.0  437.0  0.510297
# RandomForestClassifier     f_activity      1.0  1.0  437.0  0.510297
# XGBClassifier              f_activity      1.0  1.0  437.0  0.510297
#
#                                                                               \
#                                                 std  min  25%  50%  75%  max
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.500467  0.0  0.0  1.0  1.0  1.0
# KNeighborsClassifier       f_activity      0.500467  0.0  0.0  1.0  1.0  1.0
# LinearDiscriminantAnalysis f_activity      0.500467  0.0  0.0  1.0  1.0  1.0
# LinearSVC                  f_activity      0.500467  0.0  0.0  1.0  1.0  1.0
# LogisticRegression         f_activity      0.500467  0.0  0.0  1.0  1.0  1.0
# RandomForestClassifier     f_activity      0.500467  0.0  0.0  1.0  1.0  1.0
# XGBClassifier              f_activity      0.500467  0.0  0.0  1.0  1.0  1.0
#
#                                           LabuteASA                           \
#                                               count      mean       std  min
# model                      activity_label
# DecisionTreeClassifier     f_activity         437.0  0.510297  0.500467  0.0
# KNeighborsClassifier       f_activity         437.0  0.510297  0.500467  0.0
# LinearDiscriminantAnalysis f_activity         437.0  0.510297  0.500467  0.0
# LinearSVC                  f_activity         437.0  0.510297  0.500467  0.0
# LogisticRegression         f_activity         437.0  0.510297  0.500467  0.0
# RandomForestClassifier     f_activity         437.0  0.510297  0.500467  0.0
# XGBClassifier              f_activity         437.0  0.510297  0.500467  0.0
#
#                                                               MolLogP  \
#                                            25%  50%  75%  max   count
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.0  1.0  1.0  1.0   437.0
# KNeighborsClassifier       f_activity      0.0  1.0  1.0  1.0   437.0
# LinearDiscriminantAnalysis f_activity      0.0  1.0  1.0  1.0   437.0
# LinearSVC                  f_activity      0.0  1.0  1.0  1.0   437.0
# LogisticRegression         f_activity      0.0  1.0  1.0  1.0   437.0
# RandomForestClassifier     f_activity      0.0  1.0  1.0  1.0   437.0
# XGBClassifier              f_activity      0.0  1.0  1.0  1.0   437.0
#
#                                                                               \
#                                                mean       std  min  25%  50%
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.510297  0.500467  0.0  0.0  1.0
# KNeighborsClassifier       f_activity      0.510297  0.500467  0.0  0.0  1.0
# LinearDiscriminantAnalysis f_activity      0.510297  0.500467  0.0  0.0  1.0
# LinearSVC                  f_activity      0.510297  0.500467  0.0  0.0  1.0
# LogisticRegression         f_activity      0.510297  0.500467  0.0  0.0  1.0
# RandomForestClassifier     f_activity      0.510297  0.500467  0.0  0.0  1.0
# XGBClassifier              f_activity      0.510297  0.500467  0.0  0.0  1.0
#
#                                                      qvina            \
#                                            75%  max  count      mean
# model                      activity_label
# DecisionTreeClassifier     f_activity      1.0  1.0  437.0  0.290618
# KNeighborsClassifier       f_activity      1.0  1.0  437.0  0.290618
# LinearDiscriminantAnalysis f_activity      1.0  1.0  437.0  0.290618
# LinearSVC                  f_activity      1.0  1.0  437.0  0.290618
# LogisticRegression         f_activity      1.0  1.0  437.0  0.290618
# RandomForestClassifier     f_activity      1.0  1.0  437.0  0.290618
# XGBClassifier              f_activity      1.0  1.0  437.0  0.290618
#
#                                                                               \
#                                                 std  min  25%  50%  75%  max
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.454568  0.0  0.0  0.0  1.0  1.0
# KNeighborsClassifier       f_activity      0.454568  0.0  0.0  0.0  1.0  1.0
# LinearDiscriminantAnalysis f_activity      0.454568  0.0  0.0  0.0  1.0  1.0
# LinearSVC                  f_activity      0.454568  0.0  0.0  0.0  1.0  1.0
# LogisticRegression         f_activity      0.454568  0.0  0.0  0.0  1.0  1.0
# RandomForestClassifier     f_activity      0.454568  0.0  0.0  0.0  1.0  1.0
# XGBClassifier              f_activity      0.454568  0.0  0.0  0.0  1.0  1.0
#
#                                           rfscore_qvina                      \
#                                                   count      mean       std
# model                      activity_label
# DecisionTreeClassifier     f_activity             437.0  0.290618  0.454568
# KNeighborsClassifier       f_activity             437.0  0.290618  0.454568
# LinearDiscriminantAnalysis f_activity             437.0  0.290618  0.454568
# LinearSVC                  f_activity             437.0  0.290618  0.454568
# LogisticRegression         f_activity             437.0  0.290618  0.454568
# RandomForestClassifier     f_activity             437.0  0.290618  0.454568
# XGBClassifier              f_activity             437.0  0.290618  0.454568
#
#                                                                    plants  \
#                                            min  25%  50%  75%  max  count
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.0  0.0  0.0  1.0  1.0  437.0
# KNeighborsClassifier       f_activity      0.0  0.0  0.0  1.0  1.0  437.0
# LinearDiscriminantAnalysis f_activity      0.0  0.0  0.0  1.0  1.0  437.0
# LinearSVC                  f_activity      0.0  0.0  0.0  1.0  1.0  437.0
# LogisticRegression         f_activity      0.0  0.0  0.0  1.0  1.0  437.0
# RandomForestClassifier     f_activity      0.0  0.0  0.0  1.0  1.0  437.0
# XGBClassifier              f_activity      0.0  0.0  0.0  1.0  1.0  437.0
#
#                                                                               \
#                                                mean       std  min  25%  50%
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.290618  0.454568  0.0  0.0  0.0
# KNeighborsClassifier       f_activity      0.290618  0.454568  0.0  0.0  0.0
# LinearDiscriminantAnalysis f_activity      0.290618  0.454568  0.0  0.0  0.0
# LinearSVC                  f_activity      0.290618  0.454568  0.0  0.0  0.0
# LogisticRegression         f_activity      0.290618  0.454568  0.0  0.0  0.0
# RandomForestClassifier     f_activity      0.290618  0.454568  0.0  0.0  0.0
# XGBClassifier              f_activity      0.290618  0.454568  0.0  0.0  0.0
#
#                                                     rfscore_plants            \
#                                            75%  max          count      mean
# model                      activity_label
# DecisionTreeClassifier     f_activity      1.0  1.0          437.0  0.290618
# KNeighborsClassifier       f_activity      1.0  1.0          437.0  0.290618
# LinearDiscriminantAnalysis f_activity      1.0  1.0          437.0  0.290618
# LinearSVC                  f_activity      1.0  1.0          437.0  0.290618
# LogisticRegression         f_activity      1.0  1.0          437.0  0.290618
# RandomForestClassifier     f_activity      1.0  1.0          437.0  0.290618
# XGBClassifier              f_activity      1.0  1.0          437.0  0.290618
#
#                                                                               \
#                                                 std  min  25%  50%  75%  max
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.454568  0.0  0.0  0.0  1.0  1.0
# KNeighborsClassifier       f_activity      0.454568  0.0  0.0  0.0  1.0  1.0
# LinearDiscriminantAnalysis f_activity      0.454568  0.0  0.0  0.0  1.0  1.0
# LinearSVC                  f_activity      0.454568  0.0  0.0  0.0  1.0  1.0
# LogisticRegression         f_activity      0.454568  0.0  0.0  0.0  1.0  1.0
# RandomForestClassifier     f_activity      0.454568  0.0  0.0  0.0  1.0  1.0
# XGBClassifier              f_activity      0.454568  0.0  0.0  0.0  1.0  1.0
#
#                                           test_mean                      \
#                                               count      mean       std
# model                      activity_label
# DecisionTreeClassifier     f_activity         437.0  0.530769  0.023320
# KNeighborsClassifier       f_activity         437.0  0.551744  0.039844
# LinearDiscriminantAnalysis f_activity         437.0  0.549514  0.038722
# LinearSVC                  f_activity         437.0  0.549394  0.038816
# LogisticRegression         f_activity         437.0  0.549216  0.039117
# RandomForestClassifier     f_activity         437.0  0.553242  0.028748
# XGBClassifier              f_activity         437.0  0.551337  0.027999
#
#                                                                          \
#                                                 min       25%       50%
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.425949  0.519384  0.534141
# KNeighborsClassifier       f_activity      0.401492  0.528599  0.557530
# LinearDiscriminantAnalysis f_activity      0.420658  0.537935  0.558939
# LinearSVC                  f_activity      0.420736  0.537754  0.558100
# LogisticRegression         f_activity      0.421007  0.535731  0.557496
# RandomForestClassifier     f_activity      0.439946  0.538739  0.557407
# XGBClassifier              f_activity      0.447309  0.539577  0.555008
#
#
#                                                 75%       max
# model                      activity_label
# DecisionTreeClassifier     f_activity      0.545841  0.581498
# KNeighborsClassifier       f_activity      0.579432  0.635578
# LinearDiscriminantAnalysis f_activity      0.574171  0.614530
# LinearSVC                  f_activity      0.573524  0.617390
# LogisticRegression         f_activity      0.573470  0.621595
# RandomForestClassifier     f_activity      0.572771  0.611313
# XGBClassifier              f_activity      0.569085  0.615476

# %% [markdown]
# <a id='top_classifiers'></a>
# ### Performance of the top classifiers

# %%
df = scores_data[['activity_label','model',*scoring_metrics]].copy()
df[scoring_metrics] = StandardScaler().fit_transform(df[scoring_metrics])
top = pd.melt(df.groupby(['activity_label', 'model']).head(1), 
              id_vars=['activity_label','model'], value_vars=scoring_metrics)
sns.catplot(kind='point', data=top.sort_values('value', ascending=False), x='variable', y='value', 
            hue='model', row='activity_label', aspect=2, order=scoring_metrics, hue_order=model_list)
plt.suptitle('Model performance by scoring metric', y=1.05)
# Out:
# Text(0.5, 1.05, 'Model performance by scoring metric')

# %% [markdown]
# <a id='docking'></a>
# ### Docking scores and performance increment

# %%
'''
combinations = [('qvina', 'rfscore_qvina'),
                ('plants', 'rfscore_plants'),
                ('qvina', 'rfscore_qvina', 'plants'),
                ('qvina', 'rfscore_qvina', 'rfscore_plants'),
                ('qvina', 'plants', 'rfscore_plants'),
                ('rfscore_qvina', 'plants', 'rfscore_plants'),
                ('qvina', 'rfscore_qvina', 'plants', 'rfscore_plants')]
'''

df = scores_data.query('qvina == 0 and rfscore_qvina == 0 and plants == 0 and rfscore_plants == 0'
                      ).groupby('model').describe()['test_roc_auc'][['mean','max']]
df['SF'] = 'None'

tmp = scores_data.query('rfscore_qvina == 0 and plants == 0 and rfscore_plants == 0'
                       ).groupby('model').describe()['test_roc_auc'][['mean','max']]
tmp['SF'] = 'qvina'
df = df.append(tmp)

tmp = scores_data.query('qvina == 0 and plants == 0 and rfscore_plants == 0'
                       ).groupby('model').describe()['test_roc_auc'][['mean','max']]
tmp['SF'] = 'rfscore_qvina'
df = df.append(tmp)

tmp = scores_data.query('plants == 0 and rfscore_plants == 0'
                       ).groupby('model').describe()['test_roc_auc'][['mean','max']]
tmp['SF'] = 'qvina + rfscore_qvina'
df = df.append(tmp)

tmp = scores_data.query('qvina == 0 and rfscore_qvina == 0 and rfscore_plants == 0'
                       ).groupby('model').describe()['test_roc_auc'][['mean','max']]
tmp['SF'] = 'plants'
df = df.append(tmp)

tmp = scores_data.query('qvina == 0 and rfscore_qvina == 0 and plants == 0'
                       ).groupby('model').describe()['test_roc_auc'][['mean','max']]
tmp['SF'] = 'rfscore_plants'
df = df.append(tmp)

tmp = scores_data.query('qvina == 0 and rfscore_qvina == 0'
                       ).groupby('model').describe()['test_roc_auc'][['mean','max']]
tmp['SF'] = 'plants + rfscore_plants'
df = df.append(tmp)

del tmp
df.reset_index(inplace=True)
df.sort_values(['model','mean','max'], inplace=True)

sns.catplot(kind='bar', data=df, x='model', y='max', hue='SF', orient='v', aspect=2.5, order=model_list)
plt.suptitle('test_roc_auc', y=1.05)
plt.show()

# %% [markdown]
# The barplot above indicates the performance scores don't increase when docking scores are taken into account. In fact, all models' average scores, and most models' top scores, are higher when only the molecular descriptors are evaluated, although "qvina" and "qvina" + "rfscore_qvina" consistently have higher scores for all models.

# %% [markdown]
# <a id='top_descriptors'></a>
# ### Top descriptors

# %%
# How frequently does each descriptor appear in the top 1% scores for each model?
N = np.ceil(0.01 * len(scores_data.query('model == "LogisticRegression"')))
tmp = pd.melt(scores_data, id_vars=['activity_label','model',*test_metrics], value_vars=trainset, value_name='count')
count = pd.DataFrame(tmp.groupby(['model','variable']).head(N).groupby(['model','variable'])['count'].value_counts())
del tmp

count.index.names = ['model','variable','value']
count.reset_index(level=[0,1,2], inplace=True)
count = count.query('value == 1').sort_values('count', ascending=False)
count.drop('value', axis=1, inplace=True)

g = sns.catplot(kind='bar', data=count, x='variable', y='count', col='model', 
                col_order=model_list, col_wrap=2, aspect=2)

# Set title
plt.suptitle('Most frequent descriptors in the top 1% scores', y=1.02)
plt.show()
